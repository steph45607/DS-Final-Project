# %%
from bs4 import BeautifulSoup
import requests
import html5lib
import re
import pandas as pd
import numpy as np

# %%
def clean_publish_year(raw_year):
    if type(raw_year) is None:
        return "Missing"
    result = re.search(r"(\b\d+)$", raw_year)
    # print(result)
    if result != None:
        return result.group(1)
    else:
        return "Missing"

def clean_rating(raw_rating):
    if type(raw_rating) is None:
        return 0
    result = re.search(r"(\b\d+.\b\d+)", raw_rating)
    if result == None:
        return 0
    else:
        return result.group(1)

def clean_raters(raw_raters):
    if type(raw_raters) is None:
        return 0
    result = re.search(r"((?:\d+,?\d+)*) ratings", raw_raters)
    if result == None:
        return 0
    else:
        return result.group(1)

# def clean_readers(raw_readers):
#     result = re.search(r"(\b\d+)", raw_readers)
#     if result == None:
#         return "None"
#     else:
#         return result.group(1)

def solve_nonetype_error(value):
    if value is not None:
        return value.text.strip()
    else:
        return "Missing"

# %%
books = []
for page in range(1, 25):
    response = requests.get("https://www.goodreads.com/shelf/show/horror?page=" + str(page))
    html_soup = BeautifulSoup(response.text, 'html5lib')
    book_container = html_soup.find_all('div', class_ = "elementList")
    for book in book_container:
        bookTitle = solve_nonetype_error(book.find('a', class_ = "bookTitle"))
       
        bookAuthor =solve_nonetype_error(book.find('a', class_ = "authorName"))

        # After(use comments)
        year = str(clean_publish_year(solve_nonetype_error(book.find('span', class_ = "greyText smallText"))))
        rating = clean_rating(solve_nonetype_error(book.find('span', class_ = "greyText smallText")))
        raters = str(clean_raters(solve_nonetype_error(book.find('span', class_ = "greyText smallText")))).replace(",", "")
        int(raters)
        if year != "Missing":
            int(year)
        # # readerNum = clean_readers(book.find('span', class_ = "greyText statistic").text.strip())
        
        # Before (use comments)
        # year = solve_nonetype_error(book.find('span', class_ = "greyText smallText"))
        # rating = solve_nonetype_error(book.find('span', class_ = "greyText smallText"))
        # raters = solve_nonetype_error(book.find('span', class_ = "greyText smallText"))
        # readerNum = book.find('span', class_ = "greyText statistic").text.strip()


        book_data = [bookTitle, bookAuthor, year, rating, raters]
        books.append(book_data)
books = pd.DataFrame(books, columns=["Title", "Author", "Year", "Rating", "Raters"])
books.head()
# Out:
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,440 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,668 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
# ...
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,441 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,669 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,441 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,669 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,441 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,744 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
# avg rating 4.26 —
#                 1,331,732 ratings  —
#                 published 1977
# avg rating 4.25 —
#                 979,429 ratings  —
#                 published 1986
# avg rating 4.01 —
#                 1,119,950 ratings  —
#                 published 1897
# avg rating 3.98 —
#                 630,669 ratings  —
#                 published 1974
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 4.04 —
#                 516,337 ratings  —
#                 published 1983
# avg rating 3.84 —
#                 1,395,676 ratings  —
#                 published 1818
# avg rating 3.83 —
#                 237,799 ratings  —
#                 published 1959
# avg rating 4.05 —
#                 398,851 ratings  —
#                 published 1975
# avg rating 4.34 —
#                 702,945 ratings  —
#                 published 1978
# avg rating 4.20 —
#                 606,417 ratings  —
#                 published 1987
# avg rating 3.68 —
#                 261,257 ratings  —
#                 published 2020
# avg rating 4.09 —
#                 149,054 ratings  —
#                 published 2000
# avg rating 4.01 —
#                 540,945 ratings  —
#                 published 1976
# avg rating 4.12 —
#                 233,162 ratings  —
#                 published 2013
# avg rating 4.01 —
#                 489,804 ratings  —
#                 published 2006
# avg rating 3.96 —
#                 172,311 ratings  —
#                 published 1962
# avg rating 3.76 —
#                 258,562 ratings  —
#                 published 1981
# avg rating 4.08 —
#                 116,623 ratings  —
#                 published 2013
# avg rating 4.19 —
#                 210,730 ratings  —
#                 published 1971
# avg rating 4.04 —
#                 170,247 ratings  —
#                 published 2014
# avg rating 3.84 —
#                 123,555 ratings  —
#                 published 2007
# avg rating 4.09 —
#                 598,467 ratings  —
#                 published 2002
# avg rating 3.95 —
#                 232,423 ratings  —
#                 published 1991
# avg rating 3.82 —
#                 223,562 ratings  —
#                 published 1983
# avg rating 3.83 —
#                 491,216 ratings  —
#                 published 1886
# avg rating 4.04 —
#                 102,266 ratings  —
#                 published 2004
# avg rating 4.02 —
#                 165,802 ratings  —
#                 published 1978
# avg rating 3.82 —
#                 143,578 ratings  —
#                 published 2020
# avg rating 3.72 —
#                 54,014 ratings  —
#                 published 2020
# avg rating 3.99 —
#                 250,144 ratings  —
#                 published 2018
# avg rating 4.02 —
#                 127,441 ratings  —
#                 published 1967
# avg rating 3.80 —
#                 65,696 ratings  —
#                 published 2015
# avg rating 3.91 —
#                 211,607 ratings  —
#                 published 1980
# avg rating 3.95 —
#                 205,848 ratings  —
#                 published 1979
# avg rating 3.66 —
#                 210,692 ratings  —
#                 published 2006
# avg rating 4.23 —
#                 517,528 ratings  —
#                 published 1988
# avg rating 3.66 —
#                 60,747 ratings  —
#                 published 2014
# avg rating 3.95 —
#                 210,595 ratings  —
#                 published 2014
# avg rating 3.93 —
#                 108,625 ratings  —
#                 published 2009
# avg rating 3.97 —
#                 68,932 ratings  —
#                 published 2016
# avg rating 4.11 —
#                 1,273,421 ratings  —
#                 published 1890
# avg rating 3.82 —
#                 52,155 ratings  —
#                 published 2014
# avg rating 3.40 —
#                 135,445 ratings  —
#                 published 1898
# avg rating 3.92 —
#                 117,749 ratings  —
#                 published 1962
# avg rating 3.91 —
#                 187,397 ratings  —
#                 published 1998
# avg rating 3.58 —
#                 140,655 ratings  —
#                 published 1987
# avg rating 3.75 —
#                 194,825 ratings  —
#                 published 1984
# avg rating 3.91 —
#                 281,724 ratings  —
#                 published 2009
# avg rating 3.80 —
#                 134,109 ratings  —
#                 published 1989
# Missing
# Missing
#                             Title        Author  Year Rating   Raters
# 0         The Shining (Paperback)  Stephen King  1977   4.26  1331732
# 1                  It (Paperback)  Stephen King  1986   4.25   979429
# 2             Dracula (Paperback)   Bram Stoker  1897   4.01  1119950
# 3  Carrie (Mass Market Paperback)  Stephen King  1974   3.98   630668
# 4   Pet Sematary (Kindle Edition)  Stephen King  1983   4.04   516337

# %%
books.to_csv("test.csv", index = False)
ata = pd.read_csv("test.csv")
ata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1248 entries, 0 to 1247
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   1248 non-null   object
#  1   Author  1248 non-null   object
#  2   Year    1248 non-null   object
#  3   Rating  1248 non-null   float64
#  4   Raters  1248 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 48.9+ KB
