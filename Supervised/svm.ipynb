# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn import datasets
from sklearn.svm import  SVC
import numpy as np
from sklearn.metrics import accuracy_score

# %%
df_combined = pd.read_csv("../CombinedBooksRandomized.csv")
df_combined.head()
# Out:
#                                                Title            Author  \
# 0  The Hiding Place: The Triumphant True Story of...   Corrie ten Boom
# 1  After Dead: What Came Next in the World of Soo...  Charlaine Harris
# 2             Far From the Madding Crowd (Paperback)      Thomas Hardy
# 3                          In Five Years (Hardcover)     Rebecca Serle
# 4                The Secret Life of Bees (Paperback)     Sue Monk Kidd
#
#    Author Average Rating  Author Votes  Review Count  Distinct Works  Year  \
# 0                   4.45        332535         13767              83  1971
# 1                   3.94       3519866        139555             197  2013
# 2                   3.86        673575         32752            1187  1874
# 3                   3.75        500043         49618              13  2020
# 4                   4.07       1745246         82644              38  2001
#
#    Rating   Raters                                             Genres  \
# 0    4.44   298203  Nonfiction,Biography,History,Christian,Classic...
# 1    3.01    15654  Fantasy,Fantasy,Paranormal,Fantasy,Fiction,Fan...
# 2    3.95   143170  Classics,Fiction,Romance,Historical,Literature...
# 3    3.81   343450  Romance,Fiction,Contemporary,Audiobook,Womens ...
# 4    4.08  1228709  Fiction,Historical,Young Adult,Classics,Histor...
#
#   worth_reading
# 0           yes
# 1            no
# 2           yes
# 3           yes
# 4           yes

# %%
minRaters=min(df_combined.Raters)
maxRaters=max(df_combined.Raters)
meanRaters=df_combined.Raters.mean()
print('Min Raters :',minRaters)
print('Max Raters :',maxRaters)
print('Mean Raters :',meanRaters)
# Out:
# Min Raters : 41
# Max Raters : 8958054
# Mean Raters : 317925.05147484096

# %%
df_combined.head()
# Out:
#                                                Title            Author  \
# 0  The Hiding Place: The Triumphant True Story of...   Corrie ten Boom
# 1  After Dead: What Came Next in the World of Soo...  Charlaine Harris
# 2             Far From the Madding Crowd (Paperback)      Thomas Hardy
# 3                          In Five Years (Hardcover)     Rebecca Serle
# 4                The Secret Life of Bees (Paperback)     Sue Monk Kidd
#
#    Author Average Rating  Author Votes  Review Count  Distinct Works  Year  \
# 0                   4.45        332535         13767              83  1971
# 1                   3.94       3519866        139555             197  2013
# 2                   3.86        673575         32752            1187  1874
# 3                   3.75        500043         49618              13  2020
# 4                   4.07       1745246         82644              38  2001
#
#    Rating   Raters                                             Genres  \
# 0    4.44   298203  Nonfiction,Biography,History,Christian,Classic...
# 1    3.01    15654  Fantasy,Fantasy,Paranormal,Fantasy,Fiction,Fan...
# 2    3.95   143170  Classics,Fiction,Romance,Historical,Literature...
# 3    3.81   343450  Romance,Fiction,Contemporary,Audiobook,Womens ...
# 4    4.08  1228709  Fiction,Historical,Young Adult,Classics,Histor...
#
#   worth_reading
# 0           yes
# 1            no
# 2           yes
# 3           yes
# 4           yes

# %%
#split dataset in features and target variable
feature_cols=["Author Average Rating", "Author Votes", "Review Count", "Distinct Works", "Year"]
X = df_combined[feature_cols] # Features
y = df_combined['worth_reading'] # Target variable

print(X)
print(y)
# Out:
#       Author Average Rating  Author Votes  Review Count  Distinct Works  Year
# 0                      4.45        332535         13767              83  1971
# 1                      3.94       3519866        139555             197  2013
# 2                      3.86        673575         32752            1187  1874
# 3                      3.75        500043         49618              13  2020
# 4                      4.07       1745246         82644              38  2001
# ...                     ...           ...           ...             ...   ...
# 1724                   4.20        817207         96336              35  2020
# 1725                   4.12        445393         46820              20  2020
# 1726                   3.86       1075244         91140              16  2007
# 1727                   4.07         81509         10169              13  2020
# 1728                   3.05         20869          1573             328  2001
#
# [1729 rows x 5 columns]
# 0       yes
# 1        no
# 2       yes
# 3       yes
# 4       yes
#        ...
# 1724    yes
# 1725    yes
# 1726    yes
# 1727    yes
# 1728     no
# Name: worth_reading, Length: 1729, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

svm_model = SVC( random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

parameter_grid = { 'C': [0.1, 1, 10, 100, 1000],
                    'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                'kernel': ['rbf']
}

grid_search = GridSearchCV(estimator=svm_model, cv = 3, param_grid= parameter_grid)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']})

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.028665      0.000472         0.027334        0.000473     0.1
# 1        0.029010      0.000830         0.026323        0.000478     0.1
# 2        0.026666      0.000473         0.024666        0.000471     0.1
# 3        0.032001      0.007072         0.026000        0.000814     0.1
# 4        0.026678      0.000481         0.023998        0.000024     0.1
# 5        0.029999      0.002944         0.026334        0.000942       1
# 6        0.032333      0.001247         0.028668        0.003091       1
# 7        0.030664      0.000944         0.028000        0.002160       1
# 8        0.028338      0.000469         0.025350        0.000465       1
# 9        0.027323      0.000473         0.023681        0.000482       1
# 10       0.030988      0.000015         0.025331        0.000473      10
# 11       0.030006      0.000001         0.025994        0.000005      10
# 12       0.029665      0.000475         0.025012        0.000013      10
# 13       0.028657      0.000930         0.024671        0.000473      10
# 14       0.027344      0.000464         0.023331        0.000474      10
# 15       0.031985      0.000014         0.026008        0.000003     100
# 16       0.034333      0.004028         0.029333        0.004029     100
# 17       0.030007      0.000006         0.026005        0.000013     100
# 18       0.029344      0.000465         0.025001        0.000814     100
# 19       0.027003      0.000005         0.023339        0.000484     100
# 20       0.030994      0.000822         0.025664        0.000468    1000
# 21       0.029343      0.000465         0.024989        0.000816    1000
# 22       0.028665      0.000454         0.024678        0.000459    1000
# 23       0.031657      0.003779         0.025336        0.000941    1000
# 24       0.028008      0.000829         0.025334        0.002625    1000
#
#    param_gamma param_kernel                                         params  \
# 0            1          rbf        {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 1          0.1          rbf      {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 2         0.01          rbf     {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 3        0.001          rbf    {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 4       0.0001          rbf   {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 5            1          rbf          {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 6          0.1          rbf        {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 7         0.01          rbf       {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 8        0.001          rbf      {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 9       0.0001          rbf     {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 10           1          rbf         {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 11         0.1          rbf       {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 12        0.01          rbf      {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 13       0.001          rbf     {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 14      0.0001          rbf    {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 15           1          rbf        {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 16         0.1          rbf      {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 17        0.01          rbf     {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 18       0.001          rbf    {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 19      0.0001          rbf   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 20           1          rbf       {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 21         0.1          rbf     {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 22        0.01          rbf    {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 23       0.001          rbf   {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 24      0.0001          rbf  {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0            0.696891           0.696891           0.696891         0.696891
# 1            0.696891           0.696891           0.696891         0.696891
# 2            0.696891           0.696891           0.696891         0.696891
# 3            0.696891           0.696891           0.696891         0.696891
# 4            0.715026           0.717617           0.720207         0.717617
# 5            0.702073           0.707254           0.709845         0.706390
# 6            0.712435           0.717617           0.717617         0.715889
# 7            0.733161           0.740933           0.733161         0.735751
# 8            0.766839           0.774611           0.769430         0.770294
# 9            0.823834           0.829016           0.818653         0.823834
# 10           0.707254           0.709845           0.712435         0.709845
# 11           0.717617           0.720207           0.717617         0.718480
# 12           0.735751           0.748705           0.738342         0.740933
# 13           0.774611           0.782383           0.772021         0.776339
# 14           0.836788           0.849741           0.836788         0.841105
# 15           0.707254           0.709845           0.712435         0.709845
# 16           0.717617           0.720207           0.717617         0.718480
# 17           0.735751           0.748705           0.738342         0.740933
# 18           0.774611           0.782383           0.772021         0.776339
# 19           0.836788           0.849741           0.836788         0.841105
# 20           0.707254           0.709845           0.712435         0.709845
# 21           0.717617           0.720207           0.717617         0.718480
# 22           0.735751           0.748705           0.738342         0.740933
# 23           0.774611           0.782383           0.772021         0.776339
# 24           0.836788           0.849741           0.836788         0.841105
#
#     std_test_score  rank_test_score
# 0     1.110223e-16               22
# 1     1.110223e-16               22
# 2     1.110223e-16               22
# 3     1.110223e-16               22
# 4     2.115276e-03               16
# 5     3.231138e-03               21
# 6     2.442510e-03               17
# 7     3.663766e-03               12
# 8     3.231138e-03                8
# 9     4.230552e-03                4
# 10    2.115276e-03               18
# 11    1.221255e-03               13
# 12    5.596495e-03                9
# 13    4.403298e-03                5
# 14    6.106276e-03                1
# 15    2.115276e-03               18
# 16    1.221255e-03               13
# 17    5.596495e-03                9
# 18    4.403298e-03                5
# 19    6.106276e-03                1
# 20    2.115276e-03               18
# 21    1.221255e-03               13
# 22    5.596495e-03                9
# 23    4.403298e-03                5
# 24    6.106276e-03                1

# %%
final_model = grid_search.best_estimator_
final_model
# Out:
# SVC(C=10, gamma=0.0001, random_state=42)

# %% [markdown]
# From the best parameters found through the gridsearch, we create the model

# %%
svm_class =SVC(C=0.1, gamma=0.0001,random_state=42)
svm_class.fit(X_train, y_train)
predictions = svm_class.predict(X_test)
predictions

from sklearn.metrics import accuracy_score, confusion_matrix

print("Trained acc: ", accuracy_score(y_train, svm_class.predict(X_train)))
print("Test accuracy:", accuracy_score(y_test, predictions))
print("Confusion matrix train: ", "\n", confusion_matrix(y_train, svm_class.predict(X_train)))
print("Confusion matrix test: ", "\n",confusion_matrix(y_test, predictions))
# Out:
# Trained acc:  0.7253886010362695
# Test accuracy: 0.7057793345008757
# Confusion matrix train:
#  [[ 33 318]
#  [  0 807]]
# Confusion matrix test:
#  [[ 10 168]
#  [  0 393]]

# %% [markdown]
# From the best parameters found through the gridsearch, we create the model

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, svm_class.predict(X_train)))
print("---------------------------------------------------------")
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           no       1.00      0.09      0.17       351
#          yes       0.72      1.00      0.84       807
#
#     accuracy                           0.73      1158
#    macro avg       0.86      0.55      0.50      1158
# weighted avg       0.80      0.73      0.63      1158
#
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#           no       1.00      0.06      0.11       178
#          yes       0.70      1.00      0.82       393
#
#     accuracy                           0.71       571
#    macro avg       0.85      0.53      0.47       571
# weighted avg       0.79      0.71      0.60       571
