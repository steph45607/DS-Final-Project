# %%
from bs4 import BeautifulSoup
import requests
import html5lib
import re
import pandas as pd

# %%
def clean_publish_year(raw_year):
    result = re.search(r".+\W+published\s*(\b\d+)", raw_year)
    if result == None:
        return "None"
    else:
        return result.group(1)

def clean_rating(raw_rating):
    result = re.search(r"(\b\d+.\b\d+)", raw_rating)
    if result == None:
        return "None"
    else:
        return result.group(1)

def clean_raters(raw_raters):
    result = re.search(r"((?:\d+,?\d+)*) ratings", raw_raters)
    if result == None:
        return "None"
    else:
        return result.group(1)

def clean_readers(raw_readers):
    result = re.search(r"(\b\d+)", raw_readers)
    if result == None:
        return "None"
    else:
        return result.group(1)

# %%
books = []
response = requests.get("https://www.goodreads.com/book/most_read")
html_soup = BeautifulSoup(response.text, 'html5lib')
book_container = html_soup.find_all('tr')
for book in book_container:
    bookTitle = book.find('a', class_ = "bookTitle").text.strip()
    bookAuthor = book.find('a', class_ = "authorName").text.strip()

    # After(use comments)
    # year = clean_publish_year(book.find('span', class_ = "greyText smallText uitext").text.strip())
    # rating = clean_rating(book.find('span', class_ = "minirating").text.strip())
    # raters = clean_raters(book.find('span', class_ = "minirating").text.strip()).replace(",", "")
    # readerNum = clean_readers(book.find('span', class_ = "greyText statistic").text.strip())
    
    # Before (use comments)
    year = book.find('span', class_ = "greyText smallText uitext").text.strip()
    rating = book.find('span', class_ = "minirating").text.strip()
    raters = book.find('span', class_ = "minirating").text.strip()
    readerNum = book.find('span', class_ = "greyText statistic").text.strip()


    book_data = [bookTitle, bookAuthor, year, rating, raters, readerNum]
    books.append(book_data)
books = pd.DataFrame(books, columns=["Title", "Author", "Year", "Rating","Raters", "Readers"])
books.head()
# Out:
#                                                Title  \
# 0                                     Laut Bercerita
# 1                                    It Ends with Us
# 2                               Jakarta Sebelum Pagi
# 3                  The Seven Husbands of Evelyn Hugo
# 4  Before the Coffee Gets Cold (Before the Coffee...
#
#                            Author  \
# 0                Leila S. Chudori
# 1                  Colleen Hoover
# 2  Ziggy Zezsyazeoviennazabrizkie
# 3             Taylor Jenkins Reid
# 4             Toshikazu Kawaguchi
#
#                                                 Year  \
# 0  4.64 avg rating — 10,150 ratings\n            ...
# 1  4.38 avg rating — 1,672,064 ratings\n         ...
# 2  4.29 avg rating — 2,695 ratings\n             ...
# 3  4.47 avg rating — 1,546,365 ratings\n         ...
# 4  3.75 avg rating — 145,206 ratings\n           ...
#
#                                 Rating                               Raters  \
# 0     4.64 avg rating — 10,150 ratings     4.64 avg rating — 10,150 ratings
# 1  4.38 avg rating — 1,672,064 ratings  4.38 avg rating — 1,672,064 ratings
# 2      4.29 avg rating — 2,695 ratings      4.29 avg rating — 2,695 ratings
# 3  4.47 avg rating — 1,546,365 ratings  4.47 avg rating — 1,546,365 ratings
# 4    3.75 avg rating — 145,206 ratings    3.75 avg rating — 145,206 ratings
#
#                              Readers
# 0  55\n               people read it
# 1  44\n               people read it
# 2  39\n               people read it
# 3  36\n               people read it
# 4  36\n               people read it

# %%
books.to_csv("Vietnam.csv", index = False)
