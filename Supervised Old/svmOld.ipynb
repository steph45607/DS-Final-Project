# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn import datasets
from sklearn.svm import  SVC
import numpy as np
from sklearn.metrics import accuracy_score

# %%
df_combined = pd.read_csv("../CombinedBooksRandomized.csv")
df_combined.head()
# Out:
#                                                Title             Author  \
# 0              The Left Hand of Darkness (Paperback)  Ursula K. Le Guin
# 1                     Wish You Were Here (Hardcover)       Jodi Picoult
# 2                     If I Had Your Face (Hardcover)        Frances Cha
# 3  I'll Be Gone in the Dark: One Woman's Obsessiv...  Michelle McNamara
# 4                                   1984 (Paperback)      George Orwell
#
#    Author Average Rating  Author Votes  Review Count  Distinct Works  Year  \
# 0                   4.07       1258005         85585             753  1969
# 1                   3.99       4447186        273761              82  2021
# 2                   3.76         41079          5356               4  2020
# 3                   4.12        210117         18190               2  2018
# 4                   4.10       8007938        201434             729  1949
#
#    Rating   Raters                                             Genres
# 0    4.09   155037  Science Fiction,Fiction,Fantasy,Classics,Scien...
# 1    3.99   153115  Fiction,Contemporary,Audiobook,Romance,Adult,A...
# 2    3.76    41078  Fiction,Contemporary,Literary Fiction,Adult,Fe...
# 3    4.12   210038  Nonfiction,Crime,Audiobook,Mystery,Mystery,His...
# 4    4.19  4034352  Classics,Fiction,Science Fiction,Science Ficti...

# %%
minRaters=min(df_combined.Raters)
maxRaters=max(df_combined.Raters)
meanRaters=df_combined.Raters.mean()
print('Min Raters :',minRaters)
print('Max Raters :',maxRaters)
print('Mean Raters :',meanRaters)
# Out:
# Min Raters : 41
# Max Raters : 8958054
# Mean Raters : 316506.9895833333

# %%
#rating class column
conditions  = [ df_combined.Rating >= 4, (df_combined.Rating < 4) & (df_combined.Rating> 2), (df_combined.Rating <= 2) ]
choices     = [ "good", 'mediocre', 'bad' ]
df_combined["rating_class"] = np.select(conditions, choices, default="bad")
#rater class column
conditions  = [ df_combined.Raters >= 25000, (df_combined.Raters < 25000) & (df_combined.Raters> 1000), (df_combined.Raters <= 1000) ]
choices     = [ "large", 'medium', 'small' ]
df_combined["raters_class"] = np.select(conditions, choices, default="small")

df_combined['worth_reading']=np.where(((df_combined.rating_class == "mediocre") & (df_combined.raters_class == "large"))|((df_combined.rating_class == "good") & ((df_combined['raters_class'] == "large")|(df_combined["raters_class"] =="medium"))) ,'yes','no')

# %%
df_combined.head()
# Out:
#                                                Title             Author  \
# 0              The Left Hand of Darkness (Paperback)  Ursula K. Le Guin
# 1                     Wish You Were Here (Hardcover)       Jodi Picoult
# 2                     If I Had Your Face (Hardcover)        Frances Cha
# 3  I'll Be Gone in the Dark: One Woman's Obsessiv...  Michelle McNamara
# 4                                   1984 (Paperback)      George Orwell
#
#    Author Average Rating  Author Votes  Review Count  Distinct Works  Year  \
# 0                   4.07       1258005         85585             753  1969
# 1                   3.99       4447186        273761              82  2021
# 2                   3.76         41079          5356               4  2020
# 3                   4.12        210117         18190               2  2018
# 4                   4.10       8007938        201434             729  1949
#
#    Rating   Raters                                             Genres  \
# 0    4.09   155037  Science Fiction,Fiction,Fantasy,Classics,Scien...
# 1    3.99   153115  Fiction,Contemporary,Audiobook,Romance,Adult,A...
# 2    3.76    41078  Fiction,Contemporary,Literary Fiction,Adult,Fe...
# 3    4.12   210038  Nonfiction,Crime,Audiobook,Mystery,Mystery,His...
# 4    4.19  4034352  Classics,Fiction,Science Fiction,Science Ficti...
#
#   rating_class raters_class worth_reading
# 0         good        large           yes
# 1     mediocre        large           yes
# 2     mediocre        large           yes
# 3         good        large           yes
# 4         good        large           yes

# %%
#split dataset in features and target variable
feature_cols=["Author Average Rating", "Author Votes", "Review Count", "Distinct Works", "Year"]
X = df_combined[feature_cols] # Features
y = df_combined['worth_reading'] # Target variable

print(X)
print(y)
# Out:
#       Author Average Rating  Author Votes  Review Count  Distinct Works  Year
# 0                      4.07       1258005         85585             753  1969
# 1                      3.99       4447186        273761              82  2021
# 2                      3.76         41079          5356               4  2020
# 3                      4.12        210117         18190               2  2018
# 4                      4.10       8007938        201434             729  1949
# ...                     ...           ...           ...             ...   ...
# 1723                   4.23        353862         48530              14  2017
# 1724                   3.87         15137          1503              60  2012
# 1725                   3.88       1385551        106047              51  2011
# 1726                   4.28        448442         25874              15  1943
# 1727                   3.58          6388           851               7  2005
#
# [1728 rows x 5 columns]
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 1723    yes
# 1724     no
# 1725    yes
# 1726    yes
# 1727     no
# Name: worth_reading, Length: 1728, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

svm_model = SVC( random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

parameter_grid = { 'C': [0.1, 1, 10, 100, 1000],
                    'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                'kernel': ['rbf']
}

grid_search = GridSearchCV(estimator=svm_model, cv = 3, param_grid= parameter_grid)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']})

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.033668      0.002494         0.030995        0.003563     0.1
# 1        0.039002      0.009272         0.032665        0.004496     0.1
# 2        0.029671      0.001714         0.027996        0.000021     0.1
# 3        0.031328      0.004030         0.030669        0.003091     0.1
# 4        0.026656      0.001265         0.026008        0.000016     0.1
# 5        0.031668      0.001696         0.028332        0.002622       1
# 6        0.029999      0.000027         0.027010        0.000015       1
# 7        0.029013      0.000789         0.026677        0.000939       1
# 8        0.028464      0.000428         0.026572        0.000426       1
# 9        0.028000      0.000002         0.025333        0.001247       1
# 10       0.032664      0.000941         0.027336        0.001250      10
# 11       0.031335      0.000474         0.027333        0.000471      10
# 12       0.031667      0.002357         0.026345        0.000464      10
# 13       0.030989      0.000821         0.027664        0.001703      10
# 14       0.029669      0.000947         0.025002        0.000008      10
# 15       0.042677      0.009478         0.030001        0.002169     100
# 16       0.031998      0.002827         0.027333        0.001887     100
# 17       0.029976      0.000815         0.034680        0.009561     100
# 18       0.032333      0.004713         0.029333        0.004714     100
# 19       0.029008      0.002846         0.027667        0.003772     100
# 20       0.034658      0.004501         0.029008        0.002821    1000
# 21       0.033655      0.002069         0.027344        0.001902    1000
# 22       0.035668      0.004053         0.031998        0.009200    1000
# 23       0.031668      0.003090         0.025334        0.000471    1000
# 24       0.027333      0.000470         0.023309        0.000440    1000
#
#    param_gamma param_kernel                                         params  \
# 0            1          rbf        {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 1          0.1          rbf      {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 2         0.01          rbf     {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 3        0.001          rbf    {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 4       0.0001          rbf   {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 5            1          rbf          {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 6          0.1          rbf        {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 7         0.01          rbf       {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 8        0.001          rbf      {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 9       0.0001          rbf     {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 10           1          rbf         {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 11         0.1          rbf       {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 12        0.01          rbf      {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 13       0.001          rbf     {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 14      0.0001          rbf    {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 15           1          rbf        {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 16         0.1          rbf      {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 17        0.01          rbf     {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 18       0.001          rbf    {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 19      0.0001          rbf   {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 20           1          rbf       {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 21         0.1          rbf     {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 22        0.01          rbf    {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 23       0.001          rbf   {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 24      0.0001          rbf  {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0            0.704663           0.707254           0.706494         0.706137
# 1            0.704663           0.707254           0.706494         0.706137
# 2            0.704663           0.707254           0.706494         0.706137
# 3            0.704663           0.707254           0.706494         0.706137
# 4            0.704663           0.722798           0.716883         0.714781
# 5            0.707254           0.712435           0.714286         0.711325
# 6            0.715026           0.715026           0.719481         0.716511
# 7            0.722798           0.733161           0.735065         0.730341
# 8            0.772021           0.764249           0.755844         0.764038
# 9            0.844560           0.818653           0.825974         0.829729
# 10           0.712435           0.715026           0.716883         0.714781
# 11           0.717617           0.720207           0.722078         0.719967
# 12           0.733161           0.740933           0.740260         0.738118
# 13           0.782383           0.779793           0.768831         0.777002
# 14           0.854922           0.836788           0.836364         0.842691
# 15           0.712435           0.715026           0.716883         0.714781
# 16           0.717617           0.720207           0.722078         0.719967
# 17           0.733161           0.740933           0.740260         0.738118
# 18           0.782383           0.779793           0.768831         0.777002
# 19           0.854922           0.836788           0.838961         0.843557
# 20           0.712435           0.715026           0.716883         0.714781
# 21           0.717617           0.720207           0.722078         0.719967
# 22           0.733161           0.740933           0.740260         0.738118
# 23           0.782383           0.779793           0.768831         0.777002
# 24           0.854922           0.836788           0.838961         0.843557
#
#     std_test_score  rank_test_score
# 0         0.001087               22
# 1         0.001087               22
# 2         0.001087               22
# 3         0.001087               22
# 4         0.007551               17
# 5         0.002976               21
# 6         0.002100               16
# 7         0.005390               12
# 8         0.006606                8
# 9         0.010905                4
# 10        0.001824               17
# 11        0.001829               13
# 12        0.003516                9
# 13        0.005874                5
# 14        0.008650                3
# 15        0.001824               17
# 16        0.001829               13
# 17        0.003516                9
# 18        0.005874                5
# 19        0.008085                1
# 20        0.001824               17
# 21        0.001829               13
# 22        0.003516                9
# 23        0.005874                5
# 24        0.008085                1

# %%
final_model = grid_search.best_estimator_
final_model
# Out:
# SVC(C=100, gamma=0.0001, random_state=42)

# %% [markdown]
# From the best parameters found through the gridsearch, we tweak some more parameters to lessen overfitting.

# %%
svm_class =SVC(C=0.1, gamma=0.0001,random_state=42)
svm_class.fit(X_train, y_train)
predictions = svm_class.predict(X_test)
predictions

from sklearn.metrics import accuracy_score, confusion_matrix

print("Trained acc: ", accuracy_score(y_train, svm_class.predict(X_train)))
print("Test accuracy:", accuracy_score(y_test, predictions))
print("Confusion matrix train: ", "\n", confusion_matrix(y_train, svm_class.predict(X_train)))
print("Confusion matrix test: ", "\n",confusion_matrix(y_test, predictions))
# Out:
# Trained acc:  0.7346585998271391
# Test accuracy: 0.691768826619965
# Confusion matrix train:
#  [[ 33 307]
#  [  0 817]]
# Confusion matrix test:
#  [[  9 176]
#  [  0 386]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, svm_class.predict(X_train)))
print("---------------------------------------------------------")
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           no       1.00      0.10      0.18       340
#          yes       0.73      1.00      0.84       817
#
#     accuracy                           0.73      1157
#    macro avg       0.86      0.55      0.51      1157
# weighted avg       0.81      0.73      0.65      1157
#
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#           no       1.00      0.05      0.09       185
#          yes       0.69      1.00      0.81       386
#
#     accuracy                           0.69       571
#    macro avg       0.84      0.52      0.45       571
# weighted avg       0.79      0.69      0.58       571
